# %% [markdown]
# ## BULK WHOIS AND IP ADDRESS SCRAPER
#
# Investigative journalists often want to find information about masses of websites, for example to find out if gambling sites are clustered in certain locations.
#
# This script lets you load an infinite list of address (into the 'checklist' area) and returns WhoIs and IP address info into a dataframe.

# %%
# libraries
import requests
from bs4 import BeautifulSoup, Tag
import numpy as np
import matplotlib.pyplot as plt
import re
import pandas as pd

# %%
# insert links here

checklist = ['https://pandas.pydata.org/',\
            'https://www.1bet2u.cc/',\
            'https://www.cashpoint.com/']

# %%
### WHOIS finder

def whois(site):
    
    whod = {}
    
    url = "https://www.whois.com/whois/" + s
    page = requests.get(url)                                
    soup = BeautifulSoup(page.content, 'html.parser')
    
    print('WHOIS: ', url)
    
    j = soup.find("div", {"class": "df-block-raw"}).contents[1].get_text()
    
    j = j.split('>>> Last update')[0]
    
    j = j.split('\n')
    
    for i in j:
        
        try:
            k,v = i.split(':',1)
            v = v.replace('\r','').strip()
            whod[k] = v
                
        except:
            continue
            
    d[s]['WhoIs'] = whod

# %%
def ipaddress(site,s):
    
    ipd = {}
    
    url = "https://check-host.net/ip-info?host=" + site
    page = requests.get(url)                                
    soup = BeautifulSoup(page.content, 'html.parser')
    
    tables = soup.find_all('table', attrs={'class':'inside_info'})

    i = 1
    for table in tables:
        
        ip_x = 'IP_'+ str(i)
        #ipd[ip_x] = {}
        i += 1
        
        rows = table.find_all('tr')

        for row in rows:
            
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]

            if len(str(cols)) < 100:
                try:

                    if cols[0] == 'IP address' or cols[0] == 'Country'  or cols[0] == 'Region'  or cols[0] == 'City':
                        
                        k = cols[0] 
                        
                        if cols[0] == 'Country':
                            v = cols[1].split('\n')[1]
                            v = v.replace('(','').replace(')','')
                        else:
                            v = cols[1]
                        
                        ipd[ip_x +': ' + k] = v
                        
                except:
                    continue
                    
    d[s]['IPs'] = ipd

# %%
# mini version for test purposes

#checklist = checklist[30:]

# %%
d = {}

for site in checklist:
    
    s = site.replace('https','').replace('http','').replace('://','').replace('www.','').replace('/','')
    d[s] = {}
    
    ipaddress(site,s)
    whois(s)
# Out:
# WHOIS:  https://www.whois.com/whois/pandas.pydata.org
# WHOIS:  https://www.whois.com/whois/1bet2u.cc
# WHOIS:  https://www.whois.com/whois/cashpoint.com

# %%
### NOTE: IF THIS STEP GIVES AN ERROR MESSAGE, IT MAY A WHOIS ISSUE. 

# Solution: click the link of the last URL and show you are not a robot

# %%
refined = {}
for a in d:
    refined[a] = {}
    for b in d[a]:
        for k,v in d[a][b].items():
            refined[a][k] = v
    
df = pd.DataFrame(refined)

df
# Out:
#                                                               pandas.pydata.org  \
# IP_1: IP address                                                   104.26.1.204
# IP_1: Country                                                                CA
# IP_1: Region                                                             Quebec
# IP_1: City                                                             Montreal
# IP_2: IP address                                                   104.26.1.204
# IP_2: Country                                                                US
# IP_2: Region                                                         California
# IP_2: City                                                        San Francisco
# IP_3: IP address                                                   104.26.1.204
# IP_3: Country                                                                US
# IP_3: Region
# IP_3: City
# Domain Name                                                          PYDATA.ORG
# Registry Domain ID                                              D164141878-LROR
# Registrar WHOIS Server                                      whois.namecheap.com
# Registrar URL                                          http://www.namecheap.com
# Updated Date                                               2019-11-26T04:18:35Z
# Creation Date                                              2011-12-16T18:38:18Z
# Registry Expiry Date                                       2028-12-16T18:38:18Z
# Registrar Registration Expiration Date
# Registrar                                                       NameCheap, Inc.
# Registrar IANA ID                                                          1068
# Registrar Abuse Contact Email                                    @namecheap.com
# Registrar Abuse Contact Phone                                     +1.6613102107
# Reseller
# Domain Status                                       ok https://icann.org/epp#ok
# Registrant Organization                                        WhoisGuard, Inc.
# Registrant State/Province                                                Panama
# Registrant Country                                                           PA
# Name Server                                           KRISTIN.NS.CLOUDFLARE.COM
# DNSSEC                                                                 unsigned
# URL of the ICANN Whois Inaccuracy Complaint For...       //www.icann.org/wicf/)
# Registry Registrant ID                                                      NaN
# Registrant Name                                                             NaN
# Registrant Street                                                           NaN
# Registrant City                                                             NaN
# Registrant Postal Code                                                      NaN
# Registrant Phone                                                            NaN
# Registrant Phone Ext                                                        NaN
# Registrant Fax                                                              NaN
# Registrant Fax Ext                                                          NaN
# Registrant Email                                                            NaN
# Registry Admin ID                                                           NaN
# Admin Name                                                                  NaN
# Admin Organization                                                          NaN
# Admin Street                                                                NaN
# Admin City                                                                  NaN
# Admin State/Province                                                        NaN
# Admin Postal Code                                                           NaN
# Admin Country                                                               NaN
# Admin Phone                                                                 NaN
# Admin Phone Ext                                                             NaN
# Admin Fax                                                                   NaN
# Admin Fax Ext                                                               NaN
# Admin Email                                                                 NaN
# Registry Tech ID                                                            NaN
# Tech Name                                                                   NaN
# Tech Organization                                                           NaN
# Tech Street                                                                 NaN
# Tech City                                                                   NaN
# Tech State/Province                                                         NaN
# Tech Postal Code                                                            NaN
# Tech Country                                                                NaN
# Tech Phone                                                                  NaN
# Tech Phone Ext                                                              NaN
# Tech Fax                                                                    NaN
# Tech Fax Ext                                                                NaN
# Tech Email                                                                  NaN
# URL of the ICANN WHOIS Data Problem Reporting S...                          NaN
#
#                                                                                             1bet2u.cc  \
# IP_1: IP address                                                                          99.86.90.54
# IP_1: Country                                                                                      FR
# IP_1: Region                                                                            Île-de-France
# IP_1: City                                                                                      Paris
# IP_2: IP address                                                                          99.86.90.54
# IP_2: Country                                                                                      FR
# IP_2: Region                                                                            Ile-de-France
# IP_2: City                                                                                      Paris
# IP_3: IP address                                                                          99.86.90.54
# IP_3: Country                                                                                      US
# IP_3: Region
# IP_3: City
# Domain Name                                                                                 1bet2u.cc
# Registry Domain ID                                                           131316734_DOMAIN_CC-VRSN
# Registrar WHOIS Server                                                              whois.godaddy.com
# Registrar URL                                                                  http://www.godaddy.com
# Updated Date                                                                     2019-09-06T06:27:59Z
# Creation Date                                                                    2017-09-05T04:10:30Z
# Registry Expiry Date                                                                              NaN
# Registrar Registration Expiration Date                                           2021-09-05T04:10:30Z
# Registrar                                                                            GoDaddy.com, LLC
# Registrar IANA ID                                                                                 146
# Registrar Abuse Contact Email                                                            @godaddy.com
# Registrar Abuse Contact Phone                                                           +1.4806242505
# Reseller                                                                                          NaN
# Domain Status                                       clientDeleteProhibited http://www.icann.org/ep...
# Registrant Organization                                                         Domains By Proxy, LLC
# Registrant State/Province                                                                     Arizona
# Registrant Country                                                                                 US
# Name Server                                                                    NS72.DOMAINCONTROL.COM
# DNSSEC                                                                                       unsigned
# URL of the ICANN Whois Inaccuracy Complaint For...                                                NaN
# Registry Registrant ID                                                    Not Available From Registry
# Registrant Name                                                                  Registration Private
# Registrant Street                                                                14455 N. Hayden Road
# Registrant City                                                                            Scottsdale
# Registrant Postal Code                                                                          85260
# Registrant Phone                                                                        +1.4806242599
# Registrant Phone Ext
# Registrant Fax                                                                          +1.4806242598
# Registrant Fax Ext
# Registrant Email                                                                  @domainsbyproxy.com
# Registry Admin ID                                                         Not Available From Registry
# Admin Name                                                                       Registration Private
# Admin Organization                                                              Domains By Proxy, LLC
# Admin Street                                                                     14455 N. Hayden Road
# Admin City                                                                                 Scottsdale
# Admin State/Province                                                                          Arizona
# Admin Postal Code                                                                               85260
# Admin Country                                                                                      US
# Admin Phone                                                                             +1.4806242599
# Admin Phone Ext
# Admin Fax                                                                               +1.4806242598
# Admin Fax Ext
# Admin Email                                                                       @domainsbyproxy.com
# Registry Tech ID                                                          Not Available From Registry
# Tech Name                                                                        Registration Private
# Tech Organization                                                               Domains By Proxy, LLC
# Tech Street                                                                      14455 N. Hayden Road
# Tech City                                                                                  Scottsdale
# Tech State/Province                                                                           Arizona
# Tech Postal Code                                                                                85260
# Tech Country                                                                                       US
# Tech Phone                                                                              +1.4806242599
# Tech Phone Ext
# Tech Fax                                                                                +1.4806242598
# Tech Fax Ext
# Tech Email                                                                        @domainsbyproxy.com
# URL of the ICANN WHOIS Data Problem Reporting S...                         http://wdprs.internic.net/
#
#                                                                                         cashpoint.com
# IP_1: IP address                                                                         99.86.90.113
# IP_1: Country                                                                                      FR
# IP_1: Region                                                                            Île-de-France
# IP_1: City                                                                                      Paris
# IP_2: IP address                                                                         99.86.90.113
# IP_2: Country                                                                                      FR
# IP_2: Region                                                                            Ile-de-France
# IP_2: City                                                                                      Paris
# IP_3: IP address                                                                         99.86.90.113
# IP_3: Country                                                                                      US
# IP_3: Region
# IP_3: City
# Domain Name                                                                             cashpoint.com
# Registry Domain ID                                                            1812607_DOMAIN_COM-VRSN
# Registrar WHOIS Server                                                                 whois.udag.net
# Registrar URL                                                          https://www.united-domains.de/
# Updated Date                                                                     2020-10-01T14:45:14Z
# Creation Date                                                                    1996-04-13T04:00:00Z
# Registry Expiry Date                                                                              NaN
# Registrar Registration Expiration Date                                           2027-04-14T04:00:00Z
# Registrar                                                                           united domains AG
# Registrar IANA ID                                                                                1408
# Registrar Abuse Contact Email                                                      @united-domains.de
# Registrar Abuse Contact Phone                                                          +49.8151368670
# Reseller
# Domain Status                                       clientTransferProhibited https://www.icann.org...
# Registrant Organization                                                                           NaN
# Registrant State/Province
# Registrant Country
# Name Server                                                                 ns01.cashpointservices.at
# DNSSEC                                                                                       unsigned
# URL of the ICANN Whois Inaccuracy Complaint For...                                                NaN
# Registry Registrant ID
# Registrant Name
# Registrant Street
# Registrant City
# Registrant Postal Code
# Registrant Phone
# Registrant Phone Ext
# Registrant Fax
# Registrant Fax Ext
# Registrant Email
# Registry Admin ID
# Admin Name
# Admin Organization                                                                                NaN
# Admin Street
# Admin City
# Admin State/Province
# Admin Postal Code
# Admin Country
# Admin Phone
# Admin Phone Ext
# Admin Fax
# Admin Fax Ext
# Admin Email
# Registry Tech ID
# Tech Name
# Tech Organization                                                                                 NaN
# Tech Street
# Tech City
# Tech State/Province
# Tech Postal Code
# Tech Country
# Tech Phone
# Tech Phone Ext
# Tech Fax
# Tech Fax Ext
# Tech Email
# URL of the ICANN WHOIS Data Problem Reporting S...                         http://wdprs.internic.net/

# %%
# pickle

#df.to_pickle("./pickledinfo.pkl")

# %% [markdown]
# ## SEPERATED VERSIONS

# %%
d = {}

for site in checklist:
    
    print('.', end='')
    
    s = site.replace('https','').replace('http','').replace('://','').replace('www.','').replace('/','')
    d[s] = {}
    
    url = "https://check-host.net/ip-info?host=" + site
    page = requests.get(url)                                
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #tables = soup.find_all('table')

    tables = soup.find_all('table', attrs={'class':'inside_info'})

    i = 1
    for table in tables:
        
        ip_x = 'IP_'+ str(i)
        d[s][ip_x] = {}
        i += 1
        
        rows = table.find_all('tr')

        for row in rows:
            
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]

            if len(str(cols)) < 100:
                try:

                    if cols[0] == 'IP address' or cols[0] == 'Country'  or cols[0] == 'Region'  or cols[0] == 'City':
                        
                        k = cols[0] 
                        
                        if cols[0] == 'Country':
                            v = cols[1].split('\n')[1]
                            v = v.replace('(','').replace(')','')
                        else:
                            v = cols[1]
                        
                        d[s][ip_x][k] = v
                        
                except:
                    continue
                    
df = pd.DataFrame.from_dict({(i,j): d[i][j] 
                           for i in d.keys() 
                           for j in d[i].keys()},
                       ).T

pd.set_option('display.max_rows', None)

df
# Out:
# ...
#                           IP address Country         Region           City
# pandas.pydata.org IP_1  104.26.1.204      CA         Quebec       Montreal
#                   IP_2  104.26.1.204      US     California  San Francisco
#                   IP_3  104.26.1.204      US
# 1bet2u.cc         IP_1   99.86.90.54      FR  Île-de-France          Paris
#                   IP_2   99.86.90.54      FR  Ile-de-France          Paris
#                   IP_3   99.86.90.54      US
# cashpoint.com     IP_1  99.86.90.113      FR  Île-de-France          Paris
#                   IP_2  99.86.90.113      FR  Ile-de-France          Paris
#                   IP_3  99.86.90.113      US

# %%
d = {}

for site in checklist:
    
    whod = {}
    
    print('.', end='')
    
    s = site.replace('https','').replace('http','').replace('://','').replace('www.','').replace('/','')
    d[s] = {}
    
    url = "https://www.whois.com/whois/" + s
    page = requests.get(url)                                
    soup = BeautifulSoup(page.content, 'html.parser')
    
    print(url)
     
    j = soup.find("div", {"class": "df-block-raw"}).contents[1].get_text()
    
    j = j.split('>>> Last update')[0]
    
    j = j.split('\n')
    
    for i in j:
        
        try:
            k,v = i.split(':',1)
            v = v.replace('\r','').strip()
            whod[k] = v
                
        except:
            continue
            
            
    d[s] = whod
            
    #for k,v in whod.items():
       # print(k,'\t\t',v)
    

dfWho = pd.DataFrame(d)

dfWho
# Out:
# .https://www.whois.com/whois/pandas.pydata.org
# .https://www.whois.com/whois/1bet2u.cc
# .https://www.whois.com/whois/cashpoint.com
#                                                               pandas.pydata.org  \
# Domain Name                                                          PYDATA.ORG
# Registry Domain ID                                              D164141878-LROR
# Registrar WHOIS Server                                      whois.namecheap.com
# Registrar URL                                          http://www.namecheap.com
# Updated Date                                               2019-11-26T04:18:35Z
# Creation Date                                              2011-12-16T18:38:18Z
# Registry Expiry Date                                       2028-12-16T18:38:18Z
# Registrar Registration Expiration Date
# Registrar                                                       NameCheap, Inc.
# Registrar IANA ID                                                          1068
# Registrar Abuse Contact Email                                    @namecheap.com
# Registrar Abuse Contact Phone                                     +1.6613102107
# Reseller
# Domain Status                                       ok https://icann.org/epp#ok
# Registrant Organization                                        WhoisGuard, Inc.
# Registrant State/Province                                                Panama
# Registrant Country                                                           PA
# Name Server                                           KRISTIN.NS.CLOUDFLARE.COM
# DNSSEC                                                                 unsigned
# URL of the ICANN Whois Inaccuracy Complaint For...       //www.icann.org/wicf/)
# Registry Registrant ID                                                      NaN
# Registrant Name                                                             NaN
# Registrant Street                                                           NaN
# Registrant City                                                             NaN
# Registrant Postal Code                                                      NaN
# Registrant Phone                                                            NaN
# Registrant Phone Ext                                                        NaN
# Registrant Fax                                                              NaN
# Registrant Fax Ext                                                          NaN
# Registrant Email                                                            NaN
# Registry Admin ID                                                           NaN
# Admin Name                                                                  NaN
# Admin Organization                                                          NaN
# Admin Street                                                                NaN
# Admin City                                                                  NaN
# Admin State/Province                                                        NaN
# Admin Postal Code                                                           NaN
# Admin Country                                                               NaN
# Admin Phone                                                                 NaN
# Admin Phone Ext                                                             NaN
# Admin Fax                                                                   NaN
# Admin Fax Ext                                                               NaN
# Admin Email                                                                 NaN
# Registry Tech ID                                                            NaN
# Tech Name                                                                   NaN
# Tech Organization                                                           NaN
# Tech Street                                                                 NaN
# Tech City                                                                   NaN
# Tech State/Province                                                         NaN
# Tech Postal Code                                                            NaN
# Tech Country                                                                NaN
# Tech Phone                                                                  NaN
# Tech Phone Ext                                                              NaN
# Tech Fax                                                                    NaN
# Tech Fax Ext                                                                NaN
# Tech Email                                                                  NaN
# URL of the ICANN WHOIS Data Problem Reporting S...                          NaN
#
#                                                                                             1bet2u.cc  \
# Domain Name                                                                                 1bet2u.cc
# Registry Domain ID                                                           131316734_DOMAIN_CC-VRSN
# Registrar WHOIS Server                                                              whois.godaddy.com
# Registrar URL                                                                  http://www.godaddy.com
# Updated Date                                                                     2019-09-06T06:27:59Z
# Creation Date                                                                    2017-09-05T04:10:30Z
# Registry Expiry Date                                                                              NaN
# Registrar Registration Expiration Date                                           2021-09-05T04:10:30Z
# Registrar                                                                            GoDaddy.com, LLC
# Registrar IANA ID                                                                                 146
# Registrar Abuse Contact Email                                                            @godaddy.com
# Registrar Abuse Contact Phone                                                           +1.4806242505
# Reseller                                                                                          NaN
# Domain Status                                       clientDeleteProhibited http://www.icann.org/ep...
# Registrant Organization                                                         Domains By Proxy, LLC
# Registrant State/Province                                                                     Arizona
# Registrant Country                                                                                 US
# Name Server                                                                    NS72.DOMAINCONTROL.COM
# DNSSEC                                                                                       unsigned
# URL of the ICANN Whois Inaccuracy Complaint For...                                                NaN
# Registry Registrant ID                                                    Not Available From Registry
# Registrant Name                                                                  Registration Private
# Registrant Street                                                                14455 N. Hayden Road
# Registrant City                                                                            Scottsdale
# Registrant Postal Code                                                                          85260
# Registrant Phone                                                                        +1.4806242599
# Registrant Phone Ext
# Registrant Fax                                                                          +1.4806242598
# Registrant Fax Ext
# Registrant Email                                                                  @domainsbyproxy.com
# Registry Admin ID                                                         Not Available From Registry
# Admin Name                                                                       Registration Private
# Admin Organization                                                              Domains By Proxy, LLC
# Admin Street                                                                     14455 N. Hayden Road
# Admin City                                                                                 Scottsdale
# Admin State/Province                                                                          Arizona
# Admin Postal Code                                                                               85260
# Admin Country                                                                                      US
# Admin Phone                                                                             +1.4806242599
# Admin Phone Ext
# Admin Fax                                                                               +1.4806242598
# Admin Fax Ext
# Admin Email                                                                       @domainsbyproxy.com
# Registry Tech ID                                                          Not Available From Registry
# Tech Name                                                                        Registration Private
# Tech Organization                                                               Domains By Proxy, LLC
# Tech Street                                                                      14455 N. Hayden Road
# Tech City                                                                                  Scottsdale
# Tech State/Province                                                                           Arizona
# Tech Postal Code                                                                                85260
# Tech Country                                                                                       US
# Tech Phone                                                                              +1.4806242599
# Tech Phone Ext
# Tech Fax                                                                                +1.4806242598
# Tech Fax Ext
# Tech Email                                                                        @domainsbyproxy.com
# URL of the ICANN WHOIS Data Problem Reporting S...                         http://wdprs.internic.net/
#
#                                                                                         cashpoint.com
# Domain Name                                                                             cashpoint.com
# Registry Domain ID                                                            1812607_DOMAIN_COM-VRSN
# Registrar WHOIS Server                                                                 whois.udag.net
# Registrar URL                                                          https://www.united-domains.de/
# Updated Date                                                                     2020-10-01T14:45:14Z
# Creation Date                                                                    1996-04-13T04:00:00Z
# Registry Expiry Date                                                                              NaN
# Registrar Registration Expiration Date                                           2027-04-14T04:00:00Z
# Registrar                                                                           united domains AG
# Registrar IANA ID                                                                                1408
# Registrar Abuse Contact Email                                                      @united-domains.de
# Registrar Abuse Contact Phone                                                          +49.8151368670
# Reseller
# Domain Status                                       clientTransferProhibited https://www.icann.org...
# Registrant Organization                                                                           NaN
# Registrant State/Province
# Registrant Country
# Name Server                                                                 ns01.cashpointservices.at
# DNSSEC                                                                                       unsigned
# URL of the ICANN Whois Inaccuracy Complaint For...                                                NaN
# Registry Registrant ID
# Registrant Name
# Registrant Street
# Registrant City
# Registrant Postal Code
# Registrant Phone
# Registrant Phone Ext
# Registrant Fax
# Registrant Fax Ext
# Registrant Email
# Registry Admin ID
# Admin Name
# Admin Organization                                                                                NaN
# Admin Street
# Admin City
# Admin State/Province
# Admin Postal Code
# Admin Country
# Admin Phone
# Admin Phone Ext
# Admin Fax
# Admin Fax Ext
# Admin Email
# Registry Tech ID
# Tech Name
# Tech Organization                                                                                 NaN
# Tech Street
# Tech City
# Tech State/Province
# Tech Postal Code
# Tech Country
# Tech Phone
# Tech Phone Ext
# Tech Fax
# Tech Fax Ext
# Tech Email
# URL of the ICANN WHOIS Data Problem Reporting S...                         http://wdprs.internic.net/

# %% [markdown]
# -----
